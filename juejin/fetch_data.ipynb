# %%
from __future__ import print_function, absolute_import
from gm.api import *

# %%
import os
juejin_token = os.environ['juejin_token']
# 掘金的官网可以免费申请 token

set_token(juejin_token)

# %%
history_data = history(symbol='SHSE.118037', frequency='1m', start_time='2023-08-14',end_time='2023-08-18', df=True)

# %%
history_data.tail(10)
# Out:
#           symbol frequency     open     high      low    close  volume  \
# 950  SHSE.118037       60s  195.729  195.807  195.681  195.751    2970
# 951  SHSE.118037       60s  195.751  195.900  195.751  195.811    7040
# 952  SHSE.118037       60s  195.802  195.975  195.746  195.746    5760
# 953  SHSE.118037       60s  195.724  195.900  195.719  195.737    6100
# 954  SHSE.118037       60s  195.845  195.845  195.700  195.800    4090
# 955  SHSE.118037       60s  195.701  195.820  195.701  195.716    4400
# 956  SHSE.118037       60s  195.703  195.888  195.700  195.800   10660
# 957  SHSE.118037       60s  195.786  196.080  195.786  196.080    7470
# 958  SHSE.118037       60s  196.080  196.111  196.000  196.020    4390
# 959  SHSE.118037       60s  196.016  196.150  195.995  196.049   10110
#
#         amount                       bob                       eob  position  \
# 950   581416.0 2023-08-17 14:50:00+08:00 2023-08-17 14:51:00+08:00         0
# ...
