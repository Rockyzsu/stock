# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('mysql+pymysql://rocky:@raspberrypi:3306/db_daily?charset=utf8')
df = pd.read_sql('2018-03-08',engine,index_col='index')

# %%
df.head()
# Out:
#          code  name  changepercent  trade   open   high    low  settlement  \
# index
# 0      603999  读者传媒          0.558   7.21   7.13   7.23   7.13        7.17
# 1      603998  方盛制药          0.000   9.43   0.00   0.00   0.00        9.43
# 2      603997  继峰股份          2.321  11.46  11.08  11.48  11.05       11.20
# 3      603996  中新科技          0.479  16.78  16.74  16.90  16.64       16.70
# 4      603993  洛阳钼业         -4.124   8.37   8.52   8.66   8.27        8.73
#
#           volume  turnoverratio      amount      per     pb        mktcap  \
# index
# 0        1363578        0.59183     9793108   24.862  2.490  4.152960e+05
# 1              0        0.00000           0   58.938  4.066  4.063731e+05
# 2        4809305        0.76338    54562282   19.424  4.378  7.308262e+05
# 3         898350        0.86986    15063977   43.026  3.546  5.036517e+05
# 4      313648156        2.42130  2637520003  139.500  4.850  1.807856e+07
#
#                 nmc
# index
# 0      1.661184e+05
# ...
